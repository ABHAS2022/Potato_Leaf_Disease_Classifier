# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# clear()
# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/potato-disease-leaf-datasetpld/PLD_3_Classes_256/Validation/Late_Blight/Late_Blight_64.jpg
# /kaggle/input/potato-disease-leaf-datasetpld/PLD_3_Classes_256/Validation/Late_Blight/Late_Blight_106.jpg
# /kaggle/input/potato-disease-leaf-datasetpld/PLD_3_Classes_256/Validation/Late_Blight/Late_Blight_79.jpg
# /kaggle/input/potato-disease-leaf-datasetpld/PLD_3_Classes_256/Validation/Late_Blight/Late_Blight_40(1).jpg
# /kaggle/input/potato-disease-leaf-datasetpld/PLD_3_Classes_256/Validation/Late_Blight/Late_Blight_11.jpg
# /kaggle/input/potato-disease-leaf-datasetpld/PLD_3_Classes_256/Validation/Late_Blight/Late_Blight_112.jpg
# /kaggle/input/potato-disease-leaf-datasetpld/PLD_3_Classes_256/Validation/Late_Blight/Late_Blight_66.jpg
# /kaggle/input/potato-disease-leaf-datasetpld/PLD_3_Classes_256/Validation/Late_Blight/Late_Blight_32.jpg
# /kaggle/input/potato-disease-leaf-datasetpld/PLD_3_Classes_256/Validation/Late_Blight/Late_Blight_53.jpg
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#   Obtaining dependency information for ultralytics from https://files.pythonhosted.org/packages/24/93/12263b1707566bbe8f5c3fe3e4188e19315c67c5b3bcf1f1091d5d0cfd6b/ultralytics-8.0.215-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.7/645.7 kB 14.2 MB/s eta 0:00:0000:01
# ...

# %%
# !pip install ultralytics
from ultralytics import YOLO
model = YOLO('yolov8n-cls.pt')
# Out:
# ...
# 100%|██████████| 5.28M/5.28M [00:00<00:00, 65.0MB/s]

# %%
import shutil
source1 = "/kaggle/input/potato-disease-leaf-datasetpld/PLD_3_Classes_256/testing"
source2 = "/kaggle/input/potato-disease-leaf-datasetpld/PLD_3_Classes_256/training"
source3 = "/kaggle/input/potato-disease-leaf-datasetpld/PLD_3_Classes_256/validation"
destination1 = "/kaggle/output/potato-disease-leaf-datasetpld/PLD_3_Classes_256/test"
destination2 = "/kaggle/output/potato-disease-leaf-datasetpld/PLD_3_Classes_256/train"
destination3 = "/kaggle/output/potato-disease-leaf-datasetpld/PLD_3_Classes_256/val"

shutil.copytree("/kaggle/input/potato-disease-leaf-datasetpld/PLD_3_Classes_256",
"/kaggle/working/project1")
# shutil.copytree(source3,destination3)
# Out:
# '/kaggle/working/project1'

# %%
os.rename("/kaggle/working/project1/Training","/kaggle/working/project1/train")
os.rename("/kaggle/working/project1/Validation","/kaggle/working/project1/val")
os.rename("/kaggle/working/project1/Testing","/kaggle/working/project1/test")

# %%
res = model.train(data = "/kaggle/working/project1",epochs = 20)
# Out:
# Ultralytics YOLOv8.0.215 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
# ...

# %%
model1 = YOLO("/kaggle/working/runs/classify/train/weights/last.pt")

# %%
model1.val()
# Out:
# Ultralytics YOLOv8.0.215 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1438723 parameters, 0 gradients, 3.3 GFLOPs
# train: /kaggle/working/project1/train... found 3251 images in 3 classes ✅
# val: /kaggle/working/project1/val... found 416 images in 3 classes ✅
# test: /kaggle/working/project1/test... found 405 images in 3 classes ✅
# val: Scanning /kaggle/working/project1/val... 416 images, 0 corrupt: 100%|██████████| 416/416 [00:00<?, ?it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:01<00:00, 18.45it/s]
#                    all      0.993          1
# Speed: 0.2ms preprocess, 2.1ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/val
# ultralytics.utils.metrics.ClassifyMetrics object with attributes:
#
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7dfde45b6560>
# curves: []
# curves_results: []
# fitness: 0.9963942468166351
# ...

# %%
import cv2
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# img = cv2.imread("/kaggle/working/runs/classify/val/confusion_matrix.png",cv2.IMREAD_ANYCOLOR)
# cv2.imshow("Confusion Matrix",img)
plt.figure(figsize = (12,20))
img = mpimg.imread("/kaggle/working/runs/classify/val/confusion_matrix.png")
plt.imshow(img)
plt.show()

# %%
plt.figure(figsize = (12,20))
img = mpimg.imread("/kaggle/working/runs/classify/val/confusion_matrix_normalized.png")
plt.imshow(img)
plt.show()

# %%
plt.figure(figsize = (12,20))
img = mpimg.imread("/kaggle/working/runs/classify/train/results.png")
plt.imshow(img)
plt.show()
